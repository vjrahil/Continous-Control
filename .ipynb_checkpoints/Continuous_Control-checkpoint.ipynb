# %% [markdown]
# # DDPG Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from collections import deque,namedtuple
from unityagents import UnityEnvironment
import numpy as np
import torch
import torch.nn as nn
import random
import copy
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
seed = 0

# %%
# select this option to load version 1 (with a single agent) of the environment
#env = UnityEnvironment(file_name='../../Reacher_Linux_NoVis/Reacher.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726624e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %%
WEIGHT_DECAY = 0.0
ACTOR_LR = 1e-4
CRITIC_LR = 1e-4
GAMMA = .999
TAU = 1e-3
T_STEPS = 20
N_LEARN_UPDATES = 10 
BUFFER_SIZE = int(1e6)
BATCH_SIZE = 128

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')


def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    

    def __init__(self, state_size, action_size, seed, fc1_units=256, fc2_units=128):
       
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return torch.tanh(self.fc3(x))


class Critic(nn.Module):

    def __init__(self, state_size, action_size, seed, fc1_units=256, fc2_units=128):
        
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units+action_size, fc2_units)
        self.fc3 = nn.Linear(fc2_units, 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        xs = F.leaky_relu(self.fc1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.leaky_relu(self.fc2(x))
        return self.fc3(x)

class Agent():
    def __init__(self,state_size,action_size,seed,n_agents):
        
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        self.n_agents = n_agents
        
        #actor
        self.actor_target = Actor(state_size, action_size, seed).to(device)
        self.actor_local = Actor(state_size, action_size, seed).to(device)
        self.actor_optim = optim.Adam(self.actor_local.parameters(), lr=ACTOR_LR)
        
        #critic
        self.critic_target = Critic(state_size, action_size,seed).to(device)
        self.critic_local = Critic(state_size, action_size, seed).to(device)
        self.critic_optim = optim.Adam(self.critic_local.parameters(),lr=CRITIC_LR, weight_decay=WEIGHT_DECAY)
        
        #replaybuffer
        self.memory = ReplayBuffer(BUFFER_SIZE,BATCH_SIZE,seed)
        
        #Ornstein Uhlenbeck noise
        self.noise = OUNoise((n_agents,action_size),seed)
        
        
    def act(self,state,add_noise = True):
        
        state = torch.from_numpy(state).float().to(device)
        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        
        if add_noise:    
            new_action = action + self.noise.sample()
        return np.clip(new_action,-1,1)
    
    def step(self,t,state,action,reward,next_state,done):
        
        for i in range(self.n_agents):
            self.memory.add(state[i,:],action[i,:],reward[i],next_state[i,:],done[i])
        
        if t%T_STEPS !=0:
            return
        
        if len(self.memory) > BATCH_SIZE:
            for i in range(N_LEARN_UPDATES):
                experiences = self.memory.sample()
                self.learn(experiences)
    
    def learn(self,experiences):
        
        states,actions,rewards,next_states,dones = experiences
        
        #critic update
        next_state_target_action = self.actor_target(next_states)
        next_state_target = self.critic_target(next_states,next_state_target_action)
        Q_expected = rewards + (GAMMA*next_state_target*(1-dones))
        Q_actual = self.critic_local(states,actions)
        loss = F.mse_loss(Q_expected,Q_actual)
        self.critic_optim.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.critic_local.parameters(),1)
        self.critic_optim.step()
        
        #actor update
        expected_actions = self.actor_local(states)
        actor_loss = -self.critic_local(states,expected_actions).mean()
        self.actor_optim.zero_grad()
        actor_loss.backward()
        self.actor_optim.step()
        
        #soft update
        self.soft_update(self.critic_local,self.critic_target)
        self.soft_update(self.actor_local,self.actor_target)
    
    def soft_update(self,local_net,target_net):
        
        for local_param,target_param in zip(local_net.parameters(),target_net.parameters()):
            target_param.data.copy_(TAU*local_param + (1-TAU)*target_param)
    
    def reset(self):
        self.noise.reset()

class OUNoise:
    def __init__(self,action_size,seed,theta = .15,sigma = .2,mu = 0.):
        self.action_size = action_size
        self.seed = random.seed(seed)
        self.theta = theta
        self.sigma = sigma
        self.mu = mu * np.ones(action_size)
        self.reset()
    
    def reset(self):
        self.state = copy.copy(self.mu)
    
    def sample(self):
        x = self.state
        dx = self.theta*(self.mu - x) + self.sigma * np.random.standard_normal(self.action_size)
        self.state = x + dx
        return self.state
        
        

class ReplayBuffer:
    def __init__(self,buffer1,batch,seed):
        
        self.seed = random.seed(seed)
        self.batch_size = batch
        self.memory = deque(maxlen = buffer1)
        self.experience = namedtuple('Experience',field_names = ['state','action','reward','next_state','done'])
        
    def add(self,state,action,reward,next_state,done):
            
        e = self.experience(state,action,reward,next_state,done)
        self.memory.append(e)
            
    def sample(self):
            
        experiences = random.sample(self.memory,k = self.batch_size)
            
        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
        
        return (states,actions,rewards,next_states,dones)
        
    def __len__(self):
        return len(self.memory)

# %%
agent = Agent(state_size,action_size,seed,num_agents)

# %% [markdown]
# ### 4. DDPG Implementation

# %%
def ddpg(n_episodes=1000, max_t=1000):
    """ Deep Deterministic Policy Gradients
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
    """
    scores_window = deque(maxlen=100)
    scores_episode = []
     
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        
        agent.reset()
            
        scores = np.zeros(num_agents)
            
        for t in range(max_t):
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]        # send the action to the environment
            next_states = env_info.vector_observations     # get the next state
            rewards = env_info.rewards                     # get the reward
            dones = env_info.local_done        
            
            agent.step(t,states, actions, rewards, next_states, dones)
 
            states = next_states
            scores += rewards
            if t % 20:
                print('\rTimestep {}\tScore: {:.2f}\tmin: {:.2f}\tmax: {:.2f}'
                      .format(t, np.mean(scores), np.min(scores), np.max(scores)), end="") 
            if np.any(dones):
                break 
        score = np.mean(scores)
        scores_window.append(score)       # save most recent score
        scores_episode.append(score)

        print('\rEpisode {}\tScore: {:.2f}\tAverage Score: {:.2f}'.format(i_episode, score, np.mean(scores_window)), end="\n")
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
        if np.mean(scores_window)>=30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            break
            
    return scores_episode

scores = ddpg()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1	Score: 0.57	Average Score: 0.57.99
# Episode 2	Score: 0.48	Average Score: 0.53.71
# Episode 3	Score: 0.74	Average Score: 0.60.98
# Episode 4	Score: 0.71	Average Score: 0.63.65
# Episode 5	Score: 0.93	Average Score: 0.69.28
# Episode 6	Score: 0.89	Average Score: 0.72.29
# Episode 7	Score: 1.43	Average Score: 0.82.12
# Episode 8	Score: 1.47	Average Score: 0.90.18
# Episode 9	Score: 1.38	Average Score: 0.96.86
# Episode 10	Score: 1.52	Average Score: 1.0127
# Episode 11	Score: 1.27	Average Score: 1.0479
# Episode 12	Score: 1.44	Average Score: 1.0717
# Episode 13	Score: 1.57	Average Score: 1.1163
# Episode 14	Score: 1.47	Average Score: 1.1304
# Episode 15	Score: 1.52	Average Score: 1.1628
# Episode 16	Score: 1.53	Average Score: 1.1852
# Episode 17	Score: 1.30	Average Score: 1.1968
# Episode 18	Score: 1.66	Average Score: 1.2204
# Episode 19	Score: 2.21	Average Score: 1.2711
# Episode 20	Score: 1.81	Average Score: 1.2934
# Episode 21	Score: 2.79	Average Score: 1.3718
# Episode 22	Score: 2.49	Average Score: 1.4211
# Episode 23	Score: 2.56	Average Score: 1.4766
# Episode 24	Score: 2.56	Average Score: 1.5134
# Episode 25	Score: 1.91	Average Score: 1.5306
# Episode 26	Score: 2.64	Average Score: 1.5786
# Episode 27	Score: 3.07	Average Score: 1.6330
# Episode 28	Score: 3.15	Average Score: 1.6806
# Episode 29	Score: 3.20	Average Score: 1.7307
# Episode 30	Score: 2.83	Average Score: 1.7796
# Episode 31	Score: 3.11	Average Score: 1.8195
# Episode 32	Score: 4.08	Average Score: 1.8805
# Episode 33	Score: 4.64	Average Score: 1.9791
# Episode 34	Score: 4.68	Average Score: 2.0515
# Episode 35	Score: 4.84	Average Score: 2.1340
# Episode 36	Score: 4.66	Average Score: 2.2026
# Episode 37	Score: 6.35	Average Score: 2.31.16
# Episode 38	Score: 6.53	Average Score: 2.42.00
# Episode 39	Score: 5.77	Average Score: 2.51.99
# Episode 40	Score: 6.74	Average Score: 2.61.03
# Episode 41	Score: 5.68	Average Score: 2.69.01
# Episode 42	Score: 7.12	Average Score: 2.79.17
# Episode 43	Score: 10.30	Average Score: 2.97.06
# Episode 44	Score: 7.58	Average Score: 3.07.11
# Episode 45	Score: 9.34	Average Score: 3.21.29
# Episode 46	Score: 8.93	Average Score: 3.34.46
# Episode 47	Score: 9.03	Average Score: 3.46.86
# Episode 48	Score: 10.73	Average Score: 3.61.45
# Episode 49	Score: 9.95	Average Score: 3.74.53
# Episode 50	Score: 11.92	Average Score: 3.90.46
# Episode 51	Score: 13.24	Average Score: 4.09.54
# Episode 52	Score: 14.97	Average Score: 4.29.67
# Episode 53	Score: 13.99	Average Score: 4.48.86
# Episode 54	Score: 15.52	Average Score: 4.68.90
# Episode 55	Score: 14.93	Average Score: 4.87.22
# Episode 56	Score: 14.69	Average Score: 5.04.16
# Episode 57	Score: 16.36	Average Score: 5.24.01
# Episode 58	Score: 17.13	Average Score: 5.45.33
# Episode 59	Score: 19.56	Average Score: 5.695.19
# Episode 60	Score: 19.22	Average Score: 5.916.67
# Episode 61	Score: 23.05	Average Score: 6.192.54
# Episode 62	Score: 21.80	Average Score: 6.441.13
# Episode 63	Score: 23.23	Average Score: 6.712.57
# Episode 64	Score: 22.80	Average Score: 6.963.20
# Episode 65	Score: 24.76	Average Score: 7.244.04
# Episode 66	Score: 23.28	Average Score: 7.489.80
# Episode 67	Score: 26.25	Average Score: 7.764.23
# Episode 68	Score: 25.50	Average Score: 8.020.57
# Episode 69	Score: 26.30	Average Score: 8.293.29
# Episode 70	Score: 27.35	Average Score: 8.563.33
# Episode 71	Score: 30.10	Average Score: 8.866.37
# Episode 72	Score: 31.32	Average Score: 9.178.37
# Episode 73	Score: 31.45	Average Score: 9.486.79
# Episode 74	Score: 29.30	Average Score: 9.756.66
# Episode 75	Score: 30.58	Average Score: 10.02.59
# Episode 76	Score: 32.27	Average Score: 10.32.71
# Episode 77	Score: 34.26	Average Score: 10.63.77
# Episode 78	Score: 32.94	Average Score: 10.91.48
# Episode 79	Score: 33.86	Average Score: 11.20.50
# Episode 80	Score: 33.22	Average Score: 11.48.73
# Episode 81	Score: 33.98	Average Score: 11.76.57
# Episode 82	Score: 34.47	Average Score: 12.03.57
# Episode 83	Score: 34.10	Average Score: 12.30.94
# Episode 84	Score: 36.05	Average Score: 12.58.89
# Episode 85	Score: 36.09	Average Score: 12.86.02
# Episode 86	Score: 36.81	Average Score: 13.14.24
# Episode 87	Score: 36.62	Average Score: 13.41.16
# Episode 88	Score: 36.71	Average Score: 13.67.79
# Episode 89	Score: 36.46	Average Score: 13.93.89
# Episode 90	Score: 37.23	Average Score: 14.19.06
# Episode 91	Score: 37.43	Average Score: 14.44.17
# Episode 92	Score: 37.53	Average Score: 14.69.87
# Episode 93	Score: 37.64	Average Score: 14.94.22
# Episode 94	Score: 37.82	Average Score: 15.18.48
# Episode 95	Score: 37.60	Average Score: 15.42.46
# Episode 96	Score: 37.80	Average Score: 15.65.40
# Episode 97	Score: 37.60	Average Score: 15.88.39
# Episode 98	Score: 37.87	Average Score: 16.10.43
# Episode 99	Score: 37.87	Average Score: 16.32.44
# Episode 100	Score: 37.51	Average Score: 16.5411
# Episode 100	Average Score: 16.54
# Episode 101	Score: 37.61	Average Score: 16.9191
# Episode 102	Score: 37.90	Average Score: 17.2855
# Episode 103	Score: 38.21	Average Score: 17.6545
# Episode 104	Score: 38.44	Average Score: 18.0342
# Episode 105	Score: 37.50	Average Score: 18.4032
# Episode 106	Score: 38.04	Average Score: 18.7739
# Episode 107	Score: 38.20	Average Score: 19.1426
# Episode 108	Score: 37.67	Average Score: 19.5060
# Episode 109	Score: 37.87	Average Score: 19.8626
# Episode 110	Score: 38.12	Average Score: 20.2336
# Episode 111	Score: 37.81	Average Score: 20.6037
# Episode 112	Score: 37.22	Average Score: 20.9598
# Episode 113	Score: 38.17	Average Score: 21.3232
# Episode 114	Score: 38.39	Average Score: 21.6938
# Episode 115	Score: 38.43	Average Score: 22.0658
# Episode 116	Score: 38.08	Average Score: 22.4253
# Episode 117	Score: 38.26	Average Score: 22.7964
# Episode 118	Score: 38.20	Average Score: 23.1660
# Episode 119	Score: 37.31	Average Score: 23.5149
# Episode 120	Score: 37.94	Average Score: 23.8744
# Episode 121	Score: 38.34	Average Score: 24.2337
# Episode 122	Score: 38.18	Average Score: 24.5841
# Episode 123	Score: 38.56	Average Score: 24.9454
# Episode 124	Score: 38.27	Average Score: 25.3063
# Episode 125	Score: 37.86	Average Score: 25.6647
# Episode 126	Score: 37.97	Average Score: 26.0160
# Episode 127	Score: 37.84	Average Score: 26.3657
# Episode 128	Score: 38.00	Average Score: 26.7160
# Episode 129	Score: 38.22	Average Score: 27.0655
# Episode 130	Score: 37.80	Average Score: 27.4159
# Episode 131	Score: 37.23	Average Score: 27.7554
# Episode 132	Score: 38.25	Average Score: 28.0957
# Episode 133	Score: 37.89	Average Score: 28.4253
# Episode 134	Score: 37.86	Average Score: 28.7653
# Episode 135	Score: 38.11	Average Score: 29.0958
# Episode 136	Score: 38.14	Average Score: 29.4261
# Episode 137	Score: 38.20	Average Score: 29.7452
# Episode 138	Score: 37.72	Average Score: 30.0548
#
# Environment solved in 38 episodes!	Average Score: 30.05

# %% [markdown]
# # Testing Environment

# %%
A = Agent(state_size,action_size,seed,num_agents)

A.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
A.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))

for i in range(3):
    env_info = env.reset(train_mode=False)[brain_name]
    states = env_info.vector_observations
    score = np.zeros(num_agents)
    
    while True:
        actions = A.act(states)
        env_info = env.step(actions)[brain_name]
        next_states = env_info.vector_observations     
        rewards = env_info.rewards       
        dones = env_info.local_done
        score += rewards
        states = next_states
        
        if np.any(dones):
            break
        
    print('Episode : {} \t Score : {:.2f}'.format(i,np.mean(score)))
# Out:
# Episode : 0 	 Score : 38.70
# Episode : 1 	 Score : 38.12
# Episode : 2 	 Score : 38.31

# %%
env.close()
